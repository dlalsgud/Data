# %%
a = 100
print(type(a))

name = "Lee"
print(type(name))
# Out:
# <class 'int'>
# <class 'str'>

# %%
print("Yes" =='Yes')

print(2 > 1) == (5 < 10)

c= '2'
d = 2
print(c == d)
# Out:
# True
# True
# False

# %%
x = 97
y = 'a'
print(chr(x) == y)
# Out:
# True

# %%
"""
not Equals Operator
"""

a = 'a'
b= 'b'
print(a != b)
# Out:
# True

# %%
print(True or True)
print(True or False)
print(False or False)
print(1 < 2 or 3 < 1)
print(3 < 1 or 1 > 6)
print(1 == 1 or 1 < 2)
# Out:
# True
# True
# False
# True
# False
# True

# %%
"""
conditional statements
"""

puppy = "maltepoo"
is_yes = False

if puppy == "maltese":
    is_yes = True
    print("말티지 맞아요.")
    
elif puppy == "poodle":
    is_yes = True
    print("푸들 맞아요.")

else:
    print("말티푸구나")
# Out:
# 말티푸구나

# %%
"""
Exception Handling
"""

x = 1

try:
    print(y)
    print(x)
except:
    print('Error')
print("continue")
# Out:
# Error
