# %%
"""
Print() function
"""

print ("Hello World!")
print (100)

intro = "My name is "
name = "minhyung Lee"

print(intro + name+ "?")
# Out:
# Hello World!
# 100
# My name is minhyung Lee?

# %%
"""
variables
"""

user_name ="minhyung Lee"
user_age = "23 "
user_id = "201855048"
user_email = "dl5336@hs.ac.kr"

# %%
"""
Data Types: integers
"""

chairs = 2
tables = 0
broken_chairs = -1
desk = 2

# %%
"""
Data Types: Real Numbers
"""
PI = 3.14
kospi_index =3140.51
school_score = 4.1

# %%
"""
:Data Types: Strings
"""

favorite_game = "battle ground"
favorite_food = 'noodle'
favorite_place = 'valley'
favorite = favorite_game + favorite_food + favorite_place

print(favorite)
# Out:
# battel groundnoodlevalley

# %%
"""
plus_Equals
"""

a = 8
a+= 2
print(a)
# Out:
# 10

# %%
"""
Errors
"""

prind("hello world!")

안녕하세요
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-d6dabdbde5a4> in <module>
#       3 """
#       4
# ----> 5 prind("hello world!")
#       6
#       7 안녕하세요
#
# NameError: name 'prind' is not defined
